# %% [markdown]
# # 클래스와 인스턴스

# %% [markdown]
# 안내: [schoolofweb.net의 Part 1](http://schoolofweb.net/blog/posts/%ED%8C%8C%EC%9D%B4%EC%8D%AC-oop-part-1-%EA%B0%9D%EC%B2%B4-%EC%A7%80%ED%96%A5-%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8Doop%EC%9D%80-%EB%AC%B4%EC%97%87%EC%9D%B8%EA%B0%80-%EC%99%9C-%EC%82%AC%EC%9A%A9%ED%95%98%EB%8A%94%EA%B0%80/)에서 사용한 코드 일부를 수정하여 설명에 활용하였음.
# 코드 사용에 대한 보다 자세한 설명은 해당 사이트를 이용할 것 추천함.

# %% [markdown]
# ## OOP 이해 방법

# %% [markdown]
# OOP를 이론적으로 이해하려는 접근은 매우 어렵다.
# 오히려 일종의 프로그래밍 기법으로 간주하고 해당 기법을 습득하기 위해 다양한 예제를 살펴보는 것이
# OOP에 대한 보다 빠르고 정확한 이해를 얻을 수 있다.
#
# 여기서는 "클래스를 선언한 후에 인스턴스를 생성하여 프로그램을 구현하는 기법이
# 그렇지 않은 기법보다 효율적으로 프로그램을 구현하는 데에 도움을 준다"는 명제를
# 적절하게 보여주는 예제를 이용하여 OOP에 대한 이해를 돕고자 한다.

# %% [markdown]
# ## 예제: OOP가 아닌 방식

# %% [markdown]
# 히어로 캐릭터를 묘사하는 프로그램을 구현하고자 한다.
#
# #### 주의사항
#
# 여기서는 `turtle` 모듈을 사용할 때와는 달리 그래픽을 전혀 사용하지 않는다.
# 게임을 구현할 때 그래픽 요소가 매우 중요하지만 여기서는 게임 캐릭터 관련 프로그램의 핵심을
# OOP 방식으로 구현하는 과정을 소개한다.

# %% [markdown]
# ### 게임 캐릭터 하나 구현하기
#
# 아래 코드는 아이언맨 캐릭터를 묘사하는 코드이며,
# 묘사를 위해 4가지 요소를 고려하였다.
#
# * 이름(name)
# * 체력(health power)
# * 타격력(damage power)
# * 장비(inventory)
#     * 수트 방어력(suit power)
#     * 사용 무기(weapon)
#
# 코드를 실행하면 아이언맨 캐릭터가 자신을 소개하도록 만들었다.
#
# __주의:__ 컴퓨터 게임을 시작하면서 캐릭터를 선택할 때 선택된 캐릭터가 자기소개를 한다고 상상하면 된다.

# %%
hero_name = '아이언맨'
hero_health = 100
hero_damage = 200
hero_inventory = {'suit': 500, 'weapon': '레이저'}

print("제 이름은 %s입니다" % hero_name)
print("현재 저의 체력은 %s입니다." % hero_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % hero_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (hero_inventory['suit'], hero_inventory['weapon']))
# Out:
# 제 이름은 아이언맨입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.

# %% [markdown]
# #### 주의사항
# 장비(inventory)에 할당된 값의 자료형은 "사전"이다.
# 따라서 마지막 `print` 문에서 사용된 `hero_inventory['suit']`는 바로 사전의 인덱싱을 활용하였다.
#
# * `hero_inventory['suit']` = `500`
# * `hero_inventory['weapon']` = `'레이저'`

# %% [markdown]
# ### 많은 게임 캐릭터 구현하기
#
# 하나의 게임 캐릭터를 구현한다면 위와 같이 해도 전혀 문제 없다.
# 하지만 어벤져스 영화에서처럼 많은 영웅과 악당들을 구현한다면 어떻게 해야 하나?
#
# 한 가지 방식은 아래 코드에서처럼 카피-앤-페이스트(copy-and-paste)를 열심히 사용하는 것이다.

# %%
# 히어로 1
hero_1_name = '아이언맨'
hero_1_health = 100
hero_1_damage = 200
hero_1_inventory = {'suit': 500, 'weapon': '레이저'}

print("제 이름은 %s입니다" % hero_1_name)
print("현재 저의 체력은 %s입니다." % hero_1_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % hero_1_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (hero_1_inventory['suit'], hero_1_inventory['weapon']))

print("=====")

# 히어로 2
hero_2_name = '데드풀'
hero_2_health = 300
hero_2_damage = 30
hero_2_inventory = {'suit': 300,'weapon': '장검'}

print("제 이름은 %s입니다" % hero_2_name)
print("현재 저의 체력은 %s입니다." % hero_2_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % hero_2_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (hero_2_inventory['suit'], hero_2_inventory['weapon']))

print("=====")

# 히어로 3
hero_3_name = '울버린'
hero_3_health = 200
hero_3_damage = 50
hero_3_inventory = {'suit': 350, 'weapon': '클로'}

print("제 이름은 %s입니다" % hero_3_name)
print("현재 저의 체력은 %s입니다." % hero_3_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % hero_3_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (hero_3_inventory['suit'], hero_3_inventory['weapon']))

print("=====")

# 몬스터 1
monster_1_name = '고블린'
monster_1_health = 90
monster_1_damage = 30
monster_1_inventory = {'suit': 50, 'weapon': '창'}

print("제 이름은 %s입니다" % monster_1_name)
print("현재 저의 체력은 %s입니다." % monster_1_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % monster_1_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (monster_1_inventory['suit'], monster_1_inventory['weapon']))

print("=====")

# 몬스터 2
monster_2_name = '드래곤'
monster_2_health = 200
monster_2_damage = 80
monster_2_inventory = {'suit': 200, 'weapon': '화염'}

print("제 이름은 %s입니다" % monster_2_name)
print("현재 저의 체력은 %s입니다." % monster_2_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % monster_2_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (monster_2_inventory['suit'], monster_2_inventory['weapon']))

print("=====")

# 몬스터 3
monster_3_name = '뱀파이어'
monster_3_health = 80
monster_3_damage = 120
monster_3_inventory = {'suit': 1000, 'weapon': '최면술'}

print("제 이름은 %s입니다" % monster_3_name)
print("현재 저의 체력은 %s입니다." % monster_3_health)
print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % monster_3_damage)
print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
      (monster_3_inventory['suit'], monster_3_inventory['weapon']))
# Out:
# 제 이름은 아이언맨입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.
# =====
# 제 이름은 데드풀입니다
# 현재 저의 체력은 300입니다.
# 저는 공격할 때마다 상대방에게 30만큼의 손상을 줍니다.
# 제 수트의 방어력은 300이며 사용하는 무기는 장검입니다.
# =====
# 제 이름은 울버린입니다
# 현재 저의 체력은 200입니다.
# 저는 공격할 때마다 상대방에게 50만큼의 손상을 줍니다.
# 제 수트의 방어력은 350이며 사용하는 무기는 클로입니다.
# =====
# 제 이름은 고블린입니다
# 현재 저의 체력은 90입니다.
# 저는 공격할 때마다 상대방에게 30만큼의 손상을 줍니다.
# 제 수트의 방어력은 50이며 사용하는 무기는 창입니다.
# =====
# 제 이름은 드래곤입니다
# 현재 저의 체력은 200입니다.
# 저는 공격할 때마다 상대방에게 80만큼의 손상을 줍니다.
# 제 수트의 방어력은 200이며 사용하는 무기는 화염입니다.
# =====
# 제 이름은 뱀파이어입니다
# 현재 저의 체력은 80입니다.
# 저는 공격할 때마다 상대방에게 120만큼의 손상을 줍니다.
# 제 수트의 방어력은 1000이며 사용하는 무기는 최면술입니다.

# %% [markdown]
# ### 위 코드의 문제점

# %% [markdown]
# 위 코드는 많은 문제를 갖고 있다.
# 무엇보다도 카피-앤-페이스트의 남용이 심각하다.
# 그리고 아무리 카피-앤-페이스트를 활용한다 하더라도 위와 같이 코딩하면 많은 문제가
# 발생할 수 있다. 예를 들어,
#
# * 캐릭터 수가 엄청 늘어난다면?
# * 캐릭터를 묘사하는 내용이나 방법이 달라진다면?
#
# 그러면 코드의 모든 부분을 일일이 손으로 수정해야 하며,
# 카피-앤-페이스트가 별 도움이 되지 않는다.
# 생성해야 할 캐릭터가 몇 백, 몇 천개, 몇 만개 이면 어떨지 한 번 상상해본다면
# 끔찍해질 것이다.
#
# 이제 이런 문제를 어떻게 해결할 것인가를 물어야 한다.

# %% [markdown]
# ## 카피-앤-페이스트(copy-and-paste)의 문제

# %% [markdown]
# 문제를 해결하려면 발생한 문제를 다시 잘 살펴 보아야 한다.
# 문제의 왜 발생하는가?
# 모순적이게도 문제의 원인을 카피-앤-페이스트를 활용할 수 있다는 데서 찾을 수 있다.
#
# 다른 말이 아니라, 카피-앤-페이스트를 활용한다는 것은 사용되는 코드가 기본적으로 동일하다는 것을 반영한다.
# 즉, 코드의 전체 모양은 동일한데 단지 코드의 일부 값들만 수정하면 되기 때문에
# 우리는 보통 카피-앤-페이스트를 사용한다.
# 그런데 앞서의 예에서 보았듯이 카피-앤-페이스트를 많이 사용한다는 것은 결국 프로그래밍기법에 문제가
# 있다는 것을 반영한다.
#
# 그렇다면 어떻게 해야 할까?

# %% [markdown]
# ## 코드의 추상화

# %% [markdown]
# 답은 간단하다.
# 카피-앤-페이스트의 활용을 최대한 줄이는 방안을 모색해야 한다.
#
# 어떻게 줄이나?
# 역시 답은 간단하다.
# __반복되는 부분을 따로 떼어내면 된다__.
#
# 어떻게 따로 떼어내나?
# 답은 "__추상화를 이용한다__" 이다.
#
# 지금까지 추상화 개념을 구현하는 두 가지 도구를 사용했다.
# 바로 함수와 모듈이다.
#
# * 함수: 반복적으로 사용되는 코드를 함수로 만들어서 필요한 경우 해당 함수를 호출한다.
# * 모듈: 여러 파일에서 공동으로 사용되는 함수들을 하나의 모듈로 묶어서 필요한 경우 불러와서 사용한다.
#
# 이제 추상화 도구를 하나 더 소개한다.
# 바로 __클래스__이다.
# 클래스는 어찌 보면 모듈과 비슷하다.
# 모듈은 단순히 하나의 파이썬 파일이며 그 안에는 다양한 변수, 함수를 포함한 어떤 파이썬 코드도
# 포함될 수 있다.
# 반면에 클래스 안에는 변수와 함수가 선언되어 있다.

# %% [markdown]
# ### 개념의 크기 비교
#
# 클래스도 파이썬 코드의 구성요소 중에 하나이므로 클래스를 선언하는 코드도 모듈에 포함될 수 있다.
# 따라서 추상화 도구로 언급한 함수, 모듈, 클래스를 개념상의 크기로 나열한다면 다음과 같다.
#
#     함수 < 클래스 < 모듈
#
# 즉, 다음이 성립한다.
# * 모듈(파이썬 코드 파일) 안에는 임의의 함수, 변수, 클래스를 사용한 코드가 포함된다.
# * 클래스 안에는 변수화 함수가 포함된다.

# %% [markdown]
# ## OOP 방식으로 게임 캐릭터 구현하기

# %% [markdown]
# 이제 많은 캐릭터를 소개하는 위 코드를 OOP 방식으로 구현해 보자.
#
# 그러기 위해 캐릭터를 소개하는 기본적인 방식을 담은 클래스를 선언하고,
# 선언된 클래스로부터 원하는 캐릭터를 손쉽게 만들어 내는 도구인 __인스턴스 생성__ 사용법을 소개한다.

# %% [markdown]
# ### 캐릭터 클래스 선언

# %% [markdown]
# 카피-앤-페이스트를 사용하는 이유가 기본적으로 동일한 모양의 코드를 반복적으로 사용하기 때문이라고 하였다.
# 따라서 __기본적으로 동일한 모양의 코드__를 클래스로 선언한다.
#
# 위 캐릭터 구현 코드에서 기본적으로 반복되는 동일한 모양의 코드는 무엇인가를 먼저 확인하면 다음과 같다.
#
# * 히어로의 이름: name
# * 히어로의 체력: health
# * 히어로의 타격력: damage
# * 히어로의 장비: inventory
#
# 즉, 변수 네 개를 선언하는 것이 반복된다.
# 따라서 네 개의 변수를 하나의 클래스로 묶우면 되며, 클래스의 선언은 아래 모양을 갖는다.
#
# ```python
# class 클래스명(부모클래스):
#     본문
# ```
#
# __주의:__ 부모클래스는 뒤에서 상속을 다룰 때 자세히 설명한다. 여기서는 일단 `object`를 사용하도록 한다.
# `object`는 시조클래스를 가리킨다.
#
#
# 이제 캐릭터 클래스를 선언해보자

# %%
class Character(object):
    
    def __init__(self, name, health, damage, inventory):
        print("제 이름은 %s입니다" % name)
        print("현재 저의 체력은 %s입니다." % health)
        print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % damage)
        print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
              (inventory['suit'], inventory['weapon']))

# %% [markdown]
# ### 생성자
#
# 클래스를 선언할 때 항상 함께하는 함수(메소드)가 있다.
# 바로 __생성자__ 메소드인데 파이썬에서는 생성자 메소드는 __항상__ `__init__`라는 이름을 갖는다.
#
# **주의:** Java의 경우 클래스의 생성자 이름은 해당 클래스의 이름과 동일하다.

# %% [markdown]
# #### 생성자의 역할
#
# 클래스를 선언하였다고 해서 클래스를 바로 이용할 수 있지는 않다.
# `Character` 클래스의 경우 내부에 생성자 함수만 정의되어 있을 뿐 어떤 특별한 일을 수행하거나
# 어떤 값들을 지정하지는 않는다.
# 예를 들어, `Character` 클래스는 어떤 특정 히어로를 가리키고 있지 않으며,
# 대신에 히어로를 소개할 때 사용할 요소들을 생성자 함수의 인자들이 암시하고 있을 뿐이다.
#
# 반면에, `Character` 클래스로부터 "아이언맨" 캐릭터를 생성하려면
# `Character` 클래스의 인스턴스를 생성하는 과정을 밟아야 하며,
# 바로 이때 __생성자가 인스턴스를 생성하는 기능을 수행한다__.

# %% [markdown]
# #### 인스턴스와 객체
#
# 보통은 동일한 개념으로 혼동해서 사용하며, 그렇게 사용해도 별 문제는 없다.
# 다만 보다 정확한 개념 이해를 위해 두 개념의 차이점을 명시하면 다음과 같다.
#
# * 객체: 어떤 일을 완성하거나 진행하기 하기 위해 필요한 구성 요소 일반을 가리킴
# * 인스턴스: 필요한 구성 요소를 구현하기 위하여 클래스를 이용하여 생성한 구체적인 값(value)을 가리킴
#
# 예를 들어, 아이언맨, 데드풀 등 어벤저스 게임에 필요한 등장 캐릭터들과 같은 게임의 구성 요소들이 객체이며,
# `Character` 클래스를 이용하여 생성되는 값들은 `Character` 클래스의 인스턴스이다.
# 즉, 인스턴스는 필요한 (추상적인) 구성 요소를 구체적으로 구현한 대상을 의미한다.

# %% [markdown]
# #### `self` 매개변수
#
# 생성자 `__init__` 메소드의 매개변수들 중에서 가장 먼저 사용되는 `self` 매개변수는 특수한 의미를 갖는다.
# 여기서는 `self`에 대한 더 이상의 설명은 하지 않으며, 아래 두 가지 사항을
# 기억해야 한다는 점만 언급한다.
#
# * __파이썬의 경우__ 클래스 내부에 선언된 메소드들의 첫째 매개변수는
#     기본적으로 `self`라늠 매개변수를 사용한다.
#     * `self`를 사용하지 않은 메소드가 존재하며, `self` 사용하는 메소드와 역할이 다르다.
#
# * 인스턴스를 통해 클래스에 포함된 메소드를 호출할 때 `self` 매개변수에 넣을 인자는 지정하지 않으며,
#     나머지 매개변수들에 사용할 인자들만 지정하면 된다.
#
# **주의:**
# * Java의 경우 `self` 매겨변수에 해당하는 인자를 사용하지 않는다.
# * 참조: [이전](https://github.com/liganega/bpp/blob/master/notes/07a-ThinkPython-Turtle-Java-Example.ipynb)에 다룬 `Turtle` 클래스를 확인해 볼 것.

# %% [markdown]
# #### 생성자 메소드의 매개변수들의 역할
#
# `self` 매개변수를 제외한 다른 매개변수들은 인스턴스를 생성할 때
# 생성되는 인스턴스만의 특성을 지정할 값들을 전달하는 통로역할을 수행한다.
#
# 예를 들어, 아이언맨 캐릭터를 만들기 위해서 `__init__` 메소드의 `self`를 제외한
# 4 개의 매개변수를 통해 아이언맨을 특징짓는 4 개의 값들을 전달해야 한다.

# %% [markdown]
# ### 인스턴스 생성
#
# `__init__` 메소드에 인자를 전달하는 방식이 바로 인스턴스를 생성하는 방식이며,
# 아래와 같이 사용한다.
#
# ```python
# 클래스이름(self를 제외한 인자들)
# ```
#
# 예를 들어, 아이언맨 캐릭터의 인스턴스를 생성하려면 아래와 같이 실행한다.
#
# ```python
# Character('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# ```
#
# 그러면 `Character` 클래스의 생성자인 `__init__` 메소드가 파이썬 인터프리터 내부에서
# 아래와 같이 호출된다.
#
# ```python
# __init__('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# ```
#
# **주의:** 생성자인  `__init__` 의 첫째 매개변수인 `self`가 있었던 자리에는
# 생성되는 인스턴스의 이름이 자동으로 사용되며, 나머지 인자는 사용자가 지정한 값들이 순서대로 사용된다.

# %% [markdown]
# 이제 아이언맨 캐릭터를 생성하여 `ironman` 변수에 할당하여 활용해 보자.

# %%
ironman = Character('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# Out:
# 제 이름은 아이언맨입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.

# %% [markdown]
# #### 인스턴스 생성과 생성자 함수 호출

# %% [markdown]
# `ironman` 변수에 할당할 값인 아이언맨 캐릭터를 `Character` 클래스의 인스턴스로 선언하였다.
# 그런데 생성하면서 아래 결과가 함께 보여졌다.
#
# ---
# ```
# 제 이름은 아이언맨입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.
# ```
# ---
#
# 그런데 위 결과는 바로 `__init__` 메소드를 아래 인자를 사용하여 호출한 결과와 동일하다.
#
# ```python
# ('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# ```
#
# **주의:** `self`에 넣을 인자는 굳이 지정하지 않는다.
#
# 이렇듯 클래스의 인스턴스를 생성할 때 해당 클래스의 생성자가 호출된다는 사실을 확인할 수 있다.

# %% [markdown]
# #### 인스턴스 생성 반복

# %% [markdown]
# OOP 방식으로 코딩을 하는 이유는 간단하다.
# 선언된 클래스를 활용하여 코드의 중복을 피하면서 원하는 객체를 무한정 생성하기 위해서이다.
# 예를 들어, 아이언맨 이외에 다른 캐릭터들의 인스턴스를 생성하려면
# `Character` 클래스의 인스턴스를 다른 인자들을 사용하여 생성하기만 하면 된다.
#
# 지금까지의 코드를 모아 정리하면 다음과 같다.

# %%
# 캐릭터 클래스 선언
class Character(object):
    
    def __init__(self, name, health, damage, inventory):
        print("제 이름은 %s입니다" % name)
        print("현재 저의 체력은 %s입니다." % health)
        print("저는 공격할 때마다 상대방에게 %s만큼의 손상을 줍니다." % damage)
        print("제 수트의 방어력은 %d이며 사용하는 무기는 %s입니다." % \
              (inventory['suit'], inventory['weapon']))

# 캐릭터 인스턴스 생성        
ironman = Character('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
print("=====")
deadpool = Character('데드풀', 300, 30, {'suit': 300, 'weapon': '장검'})
print("=====")
wolverine = Character('울버린', 200, 50, {'suit': 350, 'weapon': '클로'})
print("=====")
goblin = Character('고블린', 90, 30, {'suit': 50, 'weapon': '창'})
print("=====")
dragon = Character('드래곤', 200, 80, {'suit': 200, 'weapon': '화염'})
print("=====")
vampire = Character('뱀파이어', 80, 120, {'suit': 1000, 'weapon': '최면술'})
# Out:
# 제 이름은 아이언맨입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.
# =====
# 제 이름은 데드풀입니다
# 현재 저의 체력은 300입니다.
# 저는 공격할 때마다 상대방에게 30만큼의 손상을 줍니다.
# 제 수트의 방어력은 300이며 사용하는 무기는 장검입니다.
# =====
# 제 이름은 울버린입니다
# 현재 저의 체력은 200입니다.
# 저는 공격할 때마다 상대방에게 50만큼의 손상을 줍니다.
# 제 수트의 방어력은 350이며 사용하는 무기는 클로입니다.
# =====
# 제 이름은 고블린입니다
# 현재 저의 체력은 90입니다.
# 저는 공격할 때마다 상대방에게 30만큼의 손상을 줍니다.
# 제 수트의 방어력은 50이며 사용하는 무기는 창입니다.
# =====
# 제 이름은 드래곤입니다
# 현재 저의 체력은 200입니다.
# 저는 공격할 때마다 상대방에게 80만큼의 손상을 줍니다.
# 제 수트의 방어력은 200이며 사용하는 무기는 화염입니다.
# =====
# 제 이름은 뱀파이어입니다
# 현재 저의 체력은 80입니다.
# 저는 공격할 때마다 상대방에게 120만큼의 손상을 줍니다.
# 제 수트의 방어력은 1000이며 사용하는 무기는 최면술입니다.

# %% [markdown]
# ## 추가 설명: `__init__` 메소드와 `self` 매개변수가 진짜로 하는 일
#
# (여기 내용은 지금 단계에서 이해가 어려울 수 있다.
# 그러한 경우 우선 무시하고 나중에 보다 깊은 이해가 필요할 때 다시
# 읽을 것을 추천한다.)
#
# ``__init__`` 메소드는 엄밀히 따지면 생성된 인스턴스를 초기화하는 기능을 수행한다.
# (이런 이유로 생성자라고 호칭하기를 꺼려하기도 한다. 하지만
# 인스턴스를 생성하는 과정에 항상 관여한다는 의미에서 생성자라고
# 불러도 전혀 문제되지 않는다는 게 일반적인 견해라고 알고 있다.)
#
# 예를 들어,
#
# ```python
# ironman = Character('아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# ```
#
# 를 실행하면, 우선 인스턴스를 하나 생성하여 메모리에 저장하고,
# `Character` 자료형의 값으로 등록시킨다.
# 이어서 메모리 주소를 `ironman`과 연결시킨 후, 바로 `__init__` 함수를 아래와 같이
# 호출한다.
# (첫째 인자로 생성된 인스턴스의 이름인 `ironman` 사용됨에 주목하라.)
#
# ```python
# __init__(ironman, '아이언맨', 100, 200, {'suit': 500, 'weapon': '레이저'})
# ```
#
# 이와 같이 `__init__` 함수가 실행하면서 (`self` 매개변수 자리에 대입되는) 인스턴스를 __초기화__ 한다.
#
# 예를 들어, 앞서 이미 `ironman` 인스턴스가 생성되었지만 다음과 같이 다르게 초기화 시킬 수 있다.

# %%
Character.__init__(ironman, '"다시 초기화된 아이언맨"', 100, 200, {'suit': 500, 'weapon': '레이저'})
# Out:
# 제 이름은 "다시 초기화된 아이언맨"입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.

# %% [markdown]
# 또는 아래와 같이 이미 생성된 인스턴스를 초기화할 수도 있으며, 이 방식을 보다 추천한다.

# %%
ironman.__init__('"또 다시 초기화된 아이언맨"', 100, 200, {'suit': 500, 'weapon': '레이저'})
# Out:
# 제 이름은 "또 다시 초기화된 아이언맨"입니다
# 현재 저의 체력은 100입니다.
# 저는 공격할 때마다 상대방에게 200만큼의 손상을 줍니다.
# 제 수트의 방어력은 500이며 사용하는 무기는 레이저입니다.

# %% [markdown]
# 위와 같이 하면 `self` 매개변수에 입력할 값을 지정하지 않아도 되며,
# 내부적으로는 위의 경우처럼 `ironman`이 자동으로 대입된다.

# %% [markdown]
# ## 결론
#
# OOP 방식을 사용한 경우와 그렇지 않은 경우의 코드를 비교해 보아라.
# 게임 캐릭터를 구현하는 경우 OOP 방식을 사용한 코드가 훨씬 간결하고 산뜻하다.
# 또한 앞서 카피-앤-페이스트를 많이 사용할 경우에 발생할 수 있는 두 가지 문제들도 해결되었다.
#
# * 캐릭터 수가 엄청 늘어난다면?
#     * 해결: 캐릭터를 한 번 더 호출하면 된다.
# * 캐릭터를 묘사하는 내용이나 방법이 달라진다면?
#     * 해결: 클래스 본문을 수정한 후에 인스턴스를 생성할 때 필요하다면 인자들을 적당히 수정하여 지정하면 된다.

# %% [markdown]
# ## 연습문제

# %% [markdown]
# 1. `Character` 클래스를 아래 조건이 만족하도록 수정하라.
#     * 히어로와 악당을 구분하는 요소인 `role`을 추가하고 캐릭터 인스터스를 생성할 때 아래 문장을 추가로 출력한다.
#         > 저는 히어로 캐릭터 입니다.
#
#         또는
#
#         > 저는 악당 캐릭터 입니다.
#
#     수정된 클래스를 이용하여 히어로와 악당 캐릭터 인스턴스를 하나씩 생성하라.
#     <br><br>
# 1. `Character` 클래스를 아래 조건이 만족되도록 수정하라.
#     * 바로 앞 문제어서처럼 히어로와 악당의 역할 구분하는 요소인 `role`을 추가하라.
#     * 장비(`inventory`)에 입력되는 사전 자료형 값에 빠르기(`speed`) 값을 추가하여
#         아래와 같은 문장이 출력되도록 하라.
#
#             > 제 수트의 방어력은 500이며, 사용하는 무기는 레이저이고, 빠르기는 200입니다.
#
#     수정된 클래스를 이용하여 히어로와 악당 캐릭터 인스턴스를 하나씩 생성하라.
#     <br><br>
